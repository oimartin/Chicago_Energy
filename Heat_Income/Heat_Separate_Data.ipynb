# %%
# Dependencies
import pandas as pd

# %%
# Energy csv import
energy_file = "../Energy_Usage_2010.csv"
energy_df = pd.read_csv(energy_file)

# %%
# Create separate dataframe to house electricity data

heat_df = energy_df[['COMMUNITY AREA NAME', 'BUILDING TYPE',
                            'BUILDING_SUBTYPE', 'THERM JANUARY 2010',
                            'THERM FEBRUARY 2010', 'THERM MARCH 2010',
                            'TERM APRIL 2010', 'THERM MAY 2010',
                            'THERM JUNE 2010', 'THERM JULY 2010',
                            'THERM AUGUST 2010', 'THERM SEPTEMBER 2010',
                            'THERM OCTOBER 2010', 'THERM NOVEMBER 2010',
                            'THERM DECEMBER 2010', 'TOTAL THERMS',
                            'GAS ACCOUNTS',
                            'THERMS TOTAL SQFT', 'THERM MEAN 2010',
                            'THERM STANDARD DEVIATION 2010', 'THERM MINIMUM 2010',
                            'THERM MAXIMUM 2010', 'THERM 1ST QUARTILE 2010', 
                            'THERM 2ND QUARTILE 2010', 'THERM 3RD QUARTILE 2010', 
                            'AVERAGE HOUSESIZE', 'OCCUPIED UNITS',
                            'OCCUPIED UNITS PERCENTAGE', 'RENTER-OCCUPIED HOUSING UNITS',
                            'RENTER-OCCUPIED HOUSING PERCENTAGE', 'OCCUPIED HOUSING UNITS',
                            'TOTAL POPULATION']]

# Check electricity_df
heat_df.head()
# Out:
#   COMMUNITY AREA NAME BUILDING TYPE BUILDING_SUBTYPE  THERM JANUARY 2010  \
# 0      Archer Heights   Residential        Multi < 7              2326.0
# 1             Ashburn   Residential         Multi 7+                 NaN
# 2      Auburn Gresham    Commercial        Multi < 7              1561.0
# 3              Austin    Commercial        Multi < 7                 NaN
# 4              Austin    Commercial        Multi < 7               310.0
#
#    THERM FEBRUARY 2010  THERM MARCH 2010  TERM APRIL 2010  THERM MAY 2010  \
# 0               2131.0            1400.0            620.0           502.0
# 1                  NaN               NaN              NaN             NaN
# 2               1388.0            1507.0            701.0           486.0
# 3                  NaN               NaN              NaN             NaN
# 4                268.0             163.0             77.0            57.0
#
#    THERM JUNE 2010  THERM JULY 2010        ...         \
# ...

# %%
# Save separate csv file of electricity data
heat_df.to_csv("HEAT_only_some_housing.csv")
