# %%
# Dependencies
import pandas as pd
import json
import requests

# %%
# Base url for grabbing data from City of Chicago (Income information)
base_url = "https://data.cityofchicago.org/resource/iqnk-2tcu.json"

# Get data from base_url in json format
health_data = requests.get(base_url).json()

# %%
# Check that we pulled data correctly from API
health_data
# Out:
# [{'assault_homicide': '7.7',
#   'below_poverty_level': '22.7',
#   'birth_rate': '16.4',
#   'breast_cancer_in_females': '23.3',
#   'cancer_all_sites': '176.9',
#   'childhood_blood_lead_level_screening': '364.7',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '25.3',
#   'community_area': '1',
#   'community_area_name': 'Rogers Park',
#   'crowded_housing': '7.9',
#   'dependency': '28.8',
#   'diabetes_related': '77.1',
#   'firearm_related': '5.2',
#   'general_fertility_rate': '62',
#   'gonorrhea_in_females': '322.5',
#   'gonorrhea_in_males': '423.3',
#   'infant_mortality_rate': '6.4',
#   'low_birth_weight': '11',
#   'lung_cancer': '36.7',
#   'no_high_school_diploma': '18.1',
#   'per_capita_income': '23714',
#   'prenatal_care_beginning_in_first_trimester': '73',
#   'preterm_births': '11.2',
#   'prostate_cancer_in_males': '21.7',
#   'stroke_cerebrovascular_disease': '33.7',
#   'teen_birth_rate': '40.8',
#   'tuberculosis': '11.4',
#   'unemployment': '7.5'},
#  {'assault_homicide': '5.8',
#   'below_poverty_level': '15.1',
#   'birth_rate': '17.3',
#   'breast_cancer_in_females': '20.2',
#   'cancer_all_sites': '155.9',
#   'childhood_blood_lead_level_screening': '331.4',
#   'childhood_lead_poisoning': '1',
#   'colorectal_cancer': '17.3',
#   'community_area': '2',
#   'community_area_name': 'West Ridge',
#   'crowded_housing': '7',
#   'dependency': '38.3',
#   'diabetes_related': '60.5',
#   'firearm_related': '3.7',
#   'general_fertility_rate': '83.3',
#   'gonorrhea_in_females': '141',
#   'gonorrhea_in_males': '205.7',
#   'infant_mortality_rate': '5.1',
#   'low_birth_weight': '8.1',
#   'lung_cancer': '36',
#   'no_high_school_diploma': '19.6',
#   'per_capita_income': '21375',
#   'prenatal_care_beginning_in_first_trimester': '71.1',
#   'preterm_births': '8.3',
#   'prostate_cancer_in_males': '14.2',
#   'stroke_cerebrovascular_disease': '34.7',
#   'teen_birth_rate': '29.9',
#   'tuberculosis': '8.9',
#   'unemployment': '7.9'},
#  {'assault_homicide': '5.4',
#   'below_poverty_level': '22.7',
#   'birth_rate': '13.1',
#   'breast_cancer_in_females': '21.3',
#   'cancer_all_sites': '183.3',
#   'childhood_blood_lead_level_screening': '353.7',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '20.5',
#   'community_area': '3',
#   'community_area_name': 'Uptown',
#   'crowded_housing': '4.6',
#   'dependency': '22.2',
#   'diabetes_related': '80',
#   'firearm_related': '4.6',
#   'general_fertility_rate': '50.5',
#   'gonorrhea_in_females': '170.8',
#   'gonorrhea_in_males': '468.7',
#   'infant_mortality_rate': '6.5',
#   'low_birth_weight': '8.3',
#   'lung_cancer': '50.5',
#   'no_high_school_diploma': '13.6',
#   'per_capita_income': '32355',
#   'prenatal_care_beginning_in_first_trimester': '77.7',
#   'preterm_births': '10.3',
#   'prostate_cancer_in_males': '25.2',
#   'stroke_cerebrovascular_disease': '41.7',
#   'teen_birth_rate': '35.1',
#   'tuberculosis': '13.6',
#   'unemployment': '7.7'},
#  {'assault_homicide': '5',
#   'below_poverty_level': '9.5',
#   'birth_rate': '17.1',
#   'breast_cancer_in_females': '21.7',
#   'cancer_all_sites': '153.2',
#   'childhood_blood_lead_level_screening': '273.3',
#   'childhood_lead_poisoning': '0.4',
#   'colorectal_cancer': '8.6',
#   'community_area': '4',
#   'community_area_name': 'Lincoln Square',
#   'crowded_housing': '3.1',
#   'dependency': '25.6',
#   'diabetes_related': '55.4',
#   'firearm_related': '6.1',
#   'general_fertility_rate': '61',
#   'gonorrhea_in_females': '98.8',
#   'gonorrhea_in_males': '195.5',
#   'infant_mortality_rate': '3.8',
#   'low_birth_weight': '8.1',
#   'lung_cancer': '43.1',
#   'no_high_school_diploma': '12.5',
#   'per_capita_income': '35503',
#   'prenatal_care_beginning_in_first_trimester': '80.5',
#   'preterm_births': '9.7',
#   'prostate_cancer_in_males': '27.6',
#   'stroke_cerebrovascular_disease': '36.9',
#   'teen_birth_rate': '38.4',
#   'tuberculosis': '8.5',
#   'unemployment': '6.8'},
#  {'assault_homicide': '1',
#   'below_poverty_level': '7.1',
#   'birth_rate': '22.4',
#   'breast_cancer_in_females': '16.6',
#   'cancer_all_sites': '152.1',
#   'childhood_blood_lead_level_screening': '178.1',
#   'childhood_lead_poisoning': '0.9',
#   'colorectal_cancer': '26.1',
#   'community_area': '5',
#   'community_area_name': 'North Center',
#   'crowded_housing': '0.2',
#   'dependency': '25.5',
#   'diabetes_related': '49.8',
#   'firearm_related': '1',
#   'general_fertility_rate': '76.2',
#   'gonorrhea_in_females': '85.4',
#   'gonorrhea_in_males': '188.6',
#   'infant_mortality_rate': '2.7',
#   'low_birth_weight': '9.1',
#   'lung_cancer': '42.4',
#   'no_high_school_diploma': '5.4',
#   'per_capita_income': '51615',
#   'prenatal_care_beginning_in_first_trimester': '80.4',
#   'preterm_births': '9.8',
#   'prostate_cancer_in_males': '15.1',
#   'stroke_cerebrovascular_disease': '41.6',
#   'teen_birth_rate': '8.4',
#   'tuberculosis': '1.9',
#   'unemployment': '4.5'},
#  {'assault_homicide': '1.4',
#   'below_poverty_level': '10.5',
#   'birth_rate': '13.5',
#   'breast_cancer_in_females': '20.1',
#   'cancer_all_sites': '126.9',
#   'childhood_blood_lead_level_screening': '179.2',
#   'childhood_lead_poisoning': '0.4',
#   'colorectal_cancer': '13',
#   'community_area': '6',
#   'community_area_name': 'Lake View',
#   'crowded_housing': '1.2',
#   'dependency': '16.5',
#   'diabetes_related': '38.5',
#   'firearm_related': '1.8',
#   'general_fertility_rate': '38.7',
#   'gonorrhea_in_females': '81.8',
#   'gonorrhea_in_males': '357.6',
#   'infant_mortality_rate': '2.2',
#   'low_birth_weight': '6.3',
#   'lung_cancer': '32.5',
#   'no_high_school_diploma': '2.9',
#   'per_capita_income': '58227',
#   'prenatal_care_beginning_in_first_trimester': '79.1',
#   'preterm_births': '8.1',
#   'prostate_cancer_in_males': '17',
#   'stroke_cerebrovascular_disease': '24.4',
#   'teen_birth_rate': '15.8',
#   'tuberculosis': '3.2',
#   'unemployment': '4.7'},
#  {'assault_homicide': '0.7',
#   'below_poverty_level': '11.8',
#   'birth_rate': '13.2',
#   'breast_cancer_in_females': '23.7',
#   'cancer_all_sites': '152.9',
#   'childhood_blood_lead_level_screening': '173.3',
#   'childhood_lead_poisoning': '0.6',
#   'colorectal_cancer': '16.7',
#   'community_area': '7',
#   'community_area_name': 'Lincoln Park',
#   'crowded_housing': '0.6',
#   'dependency': '20.4',
#   'diabetes_related': '50.1',
#   'firearm_related': '2.3',
#   'general_fertility_rate': '38.7',
#   'gonorrhea_in_females': '50.3',
#   'gonorrhea_in_males': '93.1',
#   'infant_mortality_rate': '2.4',
#   'low_birth_weight': '6.6',
#   'lung_cancer': '40',
#   'no_high_school_diploma': '4.3',
#   'per_capita_income': '71403',
#   'prenatal_care_beginning_in_first_trimester': '75.7',
#   'preterm_births': '7.8',
#   'prostate_cancer_in_males': '27.3',
#   'stroke_cerebrovascular_disease': '35.3',
#   'teen_birth_rate': '2.1',
#   'tuberculosis': '1.2',
#   'unemployment': '4.5'},
#  {'assault_homicide': '3.7',
#   'below_poverty_level': '13.4',
#   'birth_rate': '10.7',
#   'breast_cancer_in_females': '24',
#   'cancer_all_sites': '142.7',
#   'childhood_blood_lead_level_screening': '311.2',
#   'childhood_lead_poisoning': '0.1',
#   'colorectal_cancer': '15.1',
#   'community_area': '8',
#   'community_area_name': 'Near North Side',
#   'crowded_housing': '2',
#   'dependency': '23.3',
#   'diabetes_related': '27',
#   'firearm_related': '3.2',
#   'general_fertility_rate': '35.9',
#   'gonorrhea_in_females': '244.4',
#   'gonorrhea_in_males': '235.8',
#   'infant_mortality_rate': '6.5',
#   'low_birth_weight': '8.6',
#   'lung_cancer': '33.6',
#   'no_high_school_diploma': '3.4',
#   'per_capita_income': '87163',
#   'prenatal_care_beginning_in_first_trimester': '69.7',
#   'preterm_births': '9.6',
#   'prostate_cancer_in_males': '15.1',
#   'stroke_cerebrovascular_disease': '22',
#   'teen_birth_rate': '34',
#   'tuberculosis': '5.5',
#   'unemployment': '5.2'},
#  {'assault_homicide': '0',
#   'below_poverty_level': '5.1',
#   'birth_rate': '11.3',
#   'breast_cancer_in_females': '13.8',
#   'cancer_all_sites': '189.7',
#   'childhood_blood_lead_level_screening': '134.7',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '15.1',
#   'community_area': '9',
#   'community_area_name': 'Edison Park',
#   'crowded_housing': '0.6',
#   'dependency': '36.6',
#   'diabetes_related': '53',
#   'firearm_related': '7.1',
#   'general_fertility_rate': '59.5',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '4.6',
#   'low_birth_weight': '7.9',
#   'lung_cancer': '45.2',
#   'no_high_school_diploma': '8.5',
#   'per_capita_income': '38337',
#   'prenatal_care_beginning_in_first_trimester': '86.6',
#   'preterm_births': '12.6',
#   'prostate_cancer_in_males': '28',
#   'stroke_cerebrovascular_disease': '38.9',
#   'teen_birth_rate': '3.9',
#   'tuberculosis': '1.8',
#   'unemployment': '7.4'},
#  {'assault_homicide': '4.7',
#   'below_poverty_level': '5.9',
#   'birth_rate': '10.4',
#   'breast_cancer_in_females': '20.7',
#   'cancer_all_sites': '180.8',
#   'childhood_blood_lead_level_screening': '163.1',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '18.9',
#   'community_area': '10',
#   'community_area_name': 'Norwood Park',
#   'crowded_housing': '2.3',
#   'dependency': '40.6',
#   'diabetes_related': '47.3',
#   'firearm_related': '8.7',
#   'general_fertility_rate': '59.6',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '4.4',
#   'low_birth_weight': '4.9',
#   'lung_cancer': '44.5',
#   'no_high_school_diploma': '13.5',
#   'per_capita_income': '31659',
#   'prenatal_care_beginning_in_first_trimester': '89.4',
#   'preterm_births': '8.3',
#   'prostate_cancer_in_males': '26.4',
#   'stroke_cerebrovascular_disease': '45.2',
#   'teen_birth_rate': '3.4',
#   'tuberculosis': '1.6',
#   'unemployment': '7.3'},
#  {'assault_homicide': '4.8',
#   'below_poverty_level': '6.4',
#   'birth_rate': '13.8',
#   'breast_cancer_in_females': '18.4',
#   'cancer_all_sites': '208.2',
#   'childhood_blood_lead_level_screening': '236.8',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '23.2',
#   'community_area': '11',
#   'community_area_name': 'Jefferson Park',
#   'crowded_housing': '1.9',
#   'dependency': '34.4',
#   'diabetes_related': '49.2',
#   'firearm_related': '4.2',
#   'general_fertility_rate': '67.8',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '8.3',
#   'low_birth_weight': '6.6',
#   'lung_cancer': '55.7',
#   'no_high_school_diploma': '13.5',
#   'per_capita_income': '27280',
#   'prenatal_care_beginning_in_first_trimester': '82.9',
#   'preterm_births': '7.7',
#   'prostate_cancer_in_males': '32.1',
#   'stroke_cerebrovascular_disease': '41.9',
#   'teen_birth_rate': '28.6',
#   'tuberculosis': '7.1',
#   'unemployment': '9'},
#  {'assault_homicide': '3.3',
#   'below_poverty_level': '6.1',
#   'birth_rate': '10',
#   'breast_cancer_in_females': '25',
#   'cancer_all_sites': '138.7',
#   'childhood_blood_lead_level_screening': '160.8',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '14.3',
#   'community_area': '12',
#   'community_area_name': 'Forest Glen',
#   'crowded_housing': '1.3',
#   'dependency': '40.6',
#   'diabetes_related': '37.2',
#   'firearm_related': '6.2',
#   'general_fertility_rate': '60.6',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '3.8',
#   'low_birth_weight': '7.6',
#   'lung_cancer': '27',
#   'no_high_school_diploma': '6.3',
#   'per_capita_income': '41509',
#   'prenatal_care_beginning_in_first_trimester': '79.3',
#   'preterm_births': '10.3',
#   'prostate_cancer_in_males': '20.3',
#   'stroke_cerebrovascular_disease': '31',
#   'teen_birth_rate': '6.3',
#   'tuberculosis': '2.2',
#   'unemployment': '5.5'},
#  {'assault_homicide': '3',
#   'below_poverty_level': '12.4',
#   'birth_rate': '10.9',
#   'breast_cancer_in_females': '20.4',
#   'cancer_all_sites': '143.7',
#   'childhood_blood_lead_level_screening': '317.3',
#   'childhood_lead_poisoning': '0.4',
#   'colorectal_cancer': '21.9',
#   'community_area': '13',
#   'community_area_name': 'North Park',
#   'crowded_housing': '3.8',
#   'dependency': '39.7',
#   'diabetes_related': '58.9',
#   'firearm_related': '3.1',
#   'general_fertility_rate': '54.2',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '5.4',
#   'low_birth_weight': '9.7',
#   'lung_cancer': '34.7',
#   'no_high_school_diploma': '18.2',
#   'per_capita_income': '24941',
#   'prenatal_care_beginning_in_first_trimester': '79.1',
#   'preterm_births': '10.2',
#   'prostate_cancer_in_males': '14.6',
#   'stroke_cerebrovascular_disease': '26.7',
#   'teen_birth_rate': '10.5',
#   'tuberculosis': '8.9',
#   'unemployment': '7.5'},
#  {'assault_homicide': '4.7',
#   'below_poverty_level': '17.1',
#   'birth_rate': '18.3',
#   'breast_cancer_in_females': '22.9',
#   'cancer_all_sites': '158.1',
#   'childhood_blood_lead_level_screening': '374.1',
#   'childhood_lead_poisoning': '1.2',
#   'colorectal_cancer': '16.8',
#   'community_area': '14',
#   'community_area_name': 'Albany Park',
#   'crowded_housing': '11.2',
#   'dependency': '32.1',
#   'diabetes_related': '72.1',
#   'firearm_related': '5.3',
#   'general_fertility_rate': '76.5',
#   'gonorrhea_in_females': '72.9',
#   'gonorrhea_in_males': '101.8',
#   'infant_mortality_rate': '4.9',
#   'low_birth_weight': '8.5',
#   'lung_cancer': '36.9',
#   'no_high_school_diploma': '34.9',
#   'per_capita_income': '20355',
#   'prenatal_care_beginning_in_first_trimester': '73.3',
#   'preterm_births': '8.3',
#   'prostate_cancer_in_males': '13.1',
#   'stroke_cerebrovascular_disease': '39.1',
#   'teen_birth_rate': '44.5',
#   'tuberculosis': '16.8',
#   'unemployment': '9'},
#  {'assault_homicide': '3.3',
#   'below_poverty_level': '12.3',
#   'birth_rate': '14.2',
#   'breast_cancer_in_females': '23.3',
#   'cancer_all_sites': '168.7',
#   'childhood_blood_lead_level_screening': '287.3',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '15.9',
#   'community_area': '15',
#   'community_area_name': 'Portage Park',
#   'crowded_housing': '4.4',
#   'dependency': '34.6',
#   'diabetes_related': '48.2',
#   'firearm_related': '4.7',
#   'general_fertility_rate': '66.1',
#   'gonorrhea_in_females': '87.7',
#   'gonorrhea_in_males': '84.9',
#   'infant_mortality_rate': '4.7',
#   'low_birth_weight': '6.9',
#   'lung_cancer': '44.9',
#   'no_high_school_diploma': '18.7',
#   'per_capita_income': '23617',
#   'prenatal_care_beginning_in_first_trimester': '79.8',
#   'preterm_births': '8.7',
#   'prostate_cancer_in_males': '14.8',
#   'stroke_cerebrovascular_disease': '37.9',
#   'teen_birth_rate': '41.7',
#   'tuberculosis': '4',
#   'unemployment': '10.6'},
#  {'assault_homicide': '4.1',
#   'below_poverty_level': '10.8',
#   'birth_rate': '15.8',
#   'breast_cancer_in_females': '29.9',
#   'cancer_all_sites': '169.4',
#   'childhood_blood_lead_level_screening': '333.5',
#   'childhood_lead_poisoning': '0.6',
#   'colorectal_cancer': '19.2',
#   'community_area': '16',
#   'community_area_name': 'Irving Park',
#   'crowded_housing': '5.6',
#   'dependency': '31.6',
#   'diabetes_related': '60.2',
#   'firearm_related': '5.7',
#   'general_fertility_rate': '67.1',
#   'gonorrhea_in_females': '159.6',
#   'gonorrhea_in_males': '74.5',
#   'infant_mortality_rate': '5.3',
#   'low_birth_weight': '7.7',
#   'lung_cancer': '41.3',
#   'no_high_school_diploma': '22',
#   'per_capita_income': '26713',
#   'prenatal_care_beginning_in_first_trimester': '79.9',
#   'preterm_births': '10.2',
#   'prostate_cancer_in_males': '17.9',
#   'stroke_cerebrovascular_disease': '42',
#   'teen_birth_rate': '37',
#   'tuberculosis': '9.3',
#   'unemployment': '10.3'},
#  {'assault_homicide': '3.7',
#   'below_poverty_level': '8.3',
#   'birth_rate': '12.5',
#   'breast_cancer_in_females': '23.7',
#   'cancer_all_sites': '191.5',
#   'childhood_blood_lead_level_screening': '233.9',
#   'childhood_lead_poisoning': '0.1',
#   'colorectal_cancer': '25.9',
#   'community_area': '17',
#   'community_area_name': 'Dunning',
#   'crowded_housing': '4.8',
#   'dependency': '34.9',
#   'diabetes_related': '42.5',
#   'firearm_related': '5.2',
#   'general_fertility_rate': '64.7',
#   'gonorrhea_in_males': '70.1',
#   'infant_mortality_rate': '4.9',
#   'low_birth_weight': '6.8',
#   'lung_cancer': '53.9',
#   'no_high_school_diploma': '18',
#   'per_capita_income': '26347',
#   'prenatal_care_beginning_in_first_trimester': '82.7',
#   'preterm_births': '9.9',
#   'prostate_cancer_in_males': '24.4',
#   'stroke_cerebrovascular_disease': '32',
#   'teen_birth_rate': '19.9',
#   'tuberculosis': '2.4',
#   'unemployment': '8.6'},
#  {'assault_homicide': '8.6',
#   'below_poverty_level': '12.8',
#   'birth_rate': '17.1',
#   'breast_cancer_in_females': '29.9',
#   'cancer_all_sites': '151',
#   'childhood_blood_lead_level_screening': '315.5',
#   'childhood_lead_poisoning': '0.9',
#   'colorectal_cancer': '15.4',
#   'community_area': '18',
#   'community_area_name': 'Montclaire',
#   'crowded_housing': '5.8',
#   'dependency': '35',
#   'diabetes_related': '89.6',
#   'firearm_related': '6.5',
#   'general_fertility_rate': '83.5',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '4.6',
#   'low_birth_weight': '8.3',
#   'lung_cancer': '33.4',
#   'no_high_school_diploma': '28.4',
#   'per_capita_income': '21257',
#   'prenatal_care_beginning_in_first_trimester': '77.6',
#   'preterm_births': '8.8',
#   'prostate_cancer_in_males': '21.9',
#   'stroke_cerebrovascular_disease': '40.3',
#   'teen_birth_rate': '61.5',
#   'tuberculosis': '3',
#   'unemployment': '10.8'},
#  {'assault_homicide': '7',
#   'below_poverty_level': '18.6',
#   'birth_rate': '20',
#   'breast_cancer_in_females': '14.4',
#   'cancer_all_sites': '152.6',
#   'childhood_blood_lead_level_screening': '421.5',
#   'childhood_lead_poisoning': '0.8',
#   'colorectal_cancer': '17.7',
#   'community_area': '19',
#   'community_area_name': 'Belmont Cragin',
#   'crowded_housing': '10',
#   'dependency': '36.9',
#   'diabetes_related': '58.6',
#   'firearm_related': '5.5',
#   'general_fertility_rate': '88.6',
#   'gonorrhea_in_females': '95.9',
#   'gonorrhea_in_males': '140.9',
#   'infant_mortality_rate': '5.6',
#   'low_birth_weight': '6.9',
#   'lung_cancer': '37.8',
#   'no_high_school_diploma': '37',
#   'per_capita_income': '15246',
#   'prenatal_care_beginning_in_first_trimester': '74.1',
#   'preterm_births': '7.6',
#   'prostate_cancer_in_males': '27.3',
#   'stroke_cerebrovascular_disease': '38.2',
#   'teen_birth_rate': '68.2',
#   'tuberculosis': '9.4',
#   'unemployment': '11.5'},
#  {'assault_homicide': '12.7',
#   'below_poverty_level': '19.1',
#   'birth_rate': '20.3',
#   'breast_cancer_in_females': '18.4',
#   'cancer_all_sites': '135.2',
#   'childhood_blood_lead_level_screening': '394.7',
#   'childhood_lead_poisoning': '0.7',
#   'colorectal_cancer': '15.6',
#   'community_area': '20',
#   'community_area_name': 'Hermosa',
#   'crowded_housing': '8.4',
#   'dependency': '36.3',
#   'diabetes_related': '63.6',
#   'firearm_related': '11.8',
#   'general_fertility_rate': '86.7',
#   'gonorrhea_in_females': '154.5',
#   'gonorrhea_in_males': '114.3',
#   'infant_mortality_rate': '9.3',
#   'low_birth_weight': '6.7',
#   'lung_cancer': '27.7',
#   'no_high_school_diploma': '41.9',
#   'per_capita_income': '15411',
#   'prenatal_care_beginning_in_first_trimester': '77.5',
#   'preterm_births': '8.8',
#   'prostate_cancer_in_males': '25.6',
#   'stroke_cerebrovascular_disease': '27.6',
#   'teen_birth_rate': '69.7',
#   'tuberculosis': '15.8',
#   'unemployment': '12.9'},
#  {'assault_homicide': '4.7',
#   'below_poverty_level': '14.6',
#   'birth_rate': '18.5',
#   'breast_cancer_in_females': '16.6',
#   'cancer_all_sites': '133.9',
#   'childhood_blood_lead_level_screening': '373.3',
#   'childhood_lead_poisoning': '0.7',
#   'colorectal_cancer': '13.4',
#   'community_area': '21',
#   'community_area_name': 'Avondale',
#   'crowded_housing': '5.8',
#   'dependency': '30.4',
#   'diabetes_related': '52.7',
#   'firearm_related': '4.6',
#   'general_fertility_rate': '77.7',
#   'gonorrhea_in_females': '85.3',
#   'gonorrhea_in_males': '92.2',
#   'infant_mortality_rate': '5.7',
#   'low_birth_weight': '7.3',
#   'lung_cancer': '32.5',
#   'no_high_school_diploma': '25.7',
#   'per_capita_income': '20489',
#   'prenatal_care_beginning_in_first_trimester': '74.4',
#   'preterm_births': '7.5',
#   'prostate_cancer_in_males': '37.7',
#   'stroke_cerebrovascular_disease': '36',
#   'teen_birth_rate': '63.4',
#   'tuberculosis': '10.1',
#   'unemployment': '9.3'},
#  {'assault_homicide': '8.6',
#   'below_poverty_level': '17.2',
#   'birth_rate': '18.2',
#   'breast_cancer_in_females': '9.2',
#   'cancer_all_sites': '148.7',
#   'childhood_blood_lead_level_screening': '364.4',
#   'childhood_lead_poisoning': '0.9',
#   'colorectal_cancer': '13.7',
#   'community_area': '22',
#   'community_area_name': 'Logan Square',
#   'crowded_housing': '3.2',
#   'dependency': '26.7',
#   'diabetes_related': '75.7',
#   'firearm_related': '10.2',
#   'general_fertility_rate': '63.5',
#   'gonorrhea_in_females': '209',
#   'gonorrhea_in_males': '159.3',
#   'infant_mortality_rate': '4.3',
#   'low_birth_weight': '7.2',
#   'lung_cancer': '37.7',
#   'no_high_school_diploma': '18.5',
#   'per_capita_income': '29026',
#   'prenatal_care_beginning_in_first_trimester': '78.2',
#   'preterm_births': '9.4',
#   'prostate_cancer_in_males': '17.5',
#   'stroke_cerebrovascular_disease': '31.9',
#   'teen_birth_rate': '66.1',
#   'tuberculosis': '8.4',
#   'unemployment': '7.5'},
#  {'assault_homicide': '29',
#   'below_poverty_level': '32.6',
#   'birth_rate': '19.2',
#   'breast_cancer_in_females': '26.3',
#   'cancer_all_sites': '211.1',
#   'childhood_blood_lead_level_screening': '447.7',
#   'childhood_lead_poisoning': '1.3',
#   'colorectal_cancer': '26.6',
#   'community_area': '23',
#   'community_area_name': 'Humboldt Park',
#   'crowded_housing': '11.2',
#   'dependency': '38.3',
#   'diabetes_related': '94.1',
#   'firearm_related': '22.7',
#   'general_fertility_rate': '80.7',
#   'gonorrhea_in_females': '1234.7',
#   'gonorrhea_in_males': '937.5',
#   'infant_mortality_rate': '9.8',
#   'low_birth_weight': '12.3',
#   'lung_cancer': '48',
#   'no_high_school_diploma': '36.8',
#   'per_capita_income': '13391',
#   'prenatal_care_beginning_in_first_trimester': '70.9',
#   'preterm_births': '11.7',
#   'prostate_cancer_in_males': '52.5',
#   'stroke_cerebrovascular_disease': '53.5',
#   'teen_birth_rate': '77.9',
#   'tuberculosis': '9.7',
#   'unemployment': '12.3'},
#  {'assault_homicide': '8.5',
#   'below_poverty_level': '15.7',
#   'birth_rate': '18.8',
#   'breast_cancer_in_females': '14.5',
#   'cancer_all_sites': '139.6',
#   'childhood_blood_lead_level_screening': '316.6',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '12.4',
#   'community_area': '24',
#   'community_area_name': 'West Town',
#   'crowded_housing': '2',
#   'dependency': '22.9',
#   'diabetes_related': '107',
#   'firearm_related': '6.6',
#   'general_fertility_rate': '60.4',
#   'gonorrhea_in_females': '177.5',
#   'gonorrhea_in_males': '182.8',
#   'infant_mortality_rate': '5.1',
#   'low_birth_weight': '9.1',
#   'lung_cancer': '27.4',
#   'no_high_school_diploma': '13.4',
#   'per_capita_income': '39596',
#   'prenatal_care_beginning_in_first_trimester': '75.5',
#   'preterm_births': '10.8',
#   'prostate_cancer_in_males': '16.6',
#   'stroke_cerebrovascular_disease': '33.3',
#   'teen_birth_rate': '49.2',
#   'tuberculosis': '3.6',
#   'unemployment': '6'},
#  {'assault_homicide': '34.4',
#   'below_poverty_level': '27',
#   'birth_rate': '18',
#   'breast_cancer_in_females': '33.7',
#   'cancer_all_sites': '261.9',
#   'childhood_blood_lead_level_screening': '492.3',
#   'childhood_lead_poisoning': '2',
#   'colorectal_cancer': '29.8',
#   'community_area': '25',
#   'community_area_name': 'Austin',
#   'crowded_housing': '5.7',
#   'dependency': '39',
#   'diabetes_related': '113.9',
#   'firearm_related': '28.5',
#   'general_fertility_rate': '80.1',
#   'gonorrhea_in_females': '1741.1',
#   'gonorrhea_in_males': '1678.9',
#   'infant_mortality_rate': '13.3',
#   'low_birth_weight': '15.4',
#   'lung_cancer': '74.6',
#   'no_high_school_diploma': '25',
#   'per_capita_income': '15920',
#   'prenatal_care_beginning_in_first_trimester': '72.9',
#   'preterm_births': '14.3',
#   'prostate_cancer_in_males': '69.8',
#   'stroke_cerebrovascular_disease': '56.8',
#   'teen_birth_rate': '81.8',
#   'tuberculosis': '5.8',
#   'unemployment': '21'},
#  {'assault_homicide': '40',
#   'below_poverty_level': '40.3',
#   'birth_rate': '20.1',
#   'breast_cancer_in_females': '54.7',
#   'cancer_all_sites': '291.5',
#   'childhood_blood_lead_level_screening': '516.1',
#   'childhood_lead_poisoning': '1.4',
#   'colorectal_cancer': '31.4',
#   'community_area': '26',
#   'community_area_name': 'West Garfield Park',
#   'crowded_housing': '8.9',
#   'dependency': '42.5',
#   'diabetes_related': '118.2',
#   'firearm_related': '36',
#   'general_fertility_rate': '88.4',
#   'gonorrhea_in_females': '3193.3',
#   'gonorrhea_in_males': '2336.7',
#   'infant_mortality_rate': '19',
#   'low_birth_weight': '17',
#   'lung_cancer': '65.3',
#   'no_high_school_diploma': '26.2',
#   'per_capita_income': '10951',
#   'prenatal_care_beginning_in_first_trimester': '71.4',
#   'preterm_births': '17.5',
#   'prostate_cancer_in_males': '75',
#   'stroke_cerebrovascular_disease': '77',
#   'teen_birth_rate': '114.9',
#   'tuberculosis': '6.5',
#   'unemployment': '25.2'},
#  {'assault_homicide': '38.4',
#   'below_poverty_level': '39.7',
#   'birth_rate': '19.4',
#   'breast_cancer_in_females': '21.7',
#   'cancer_all_sites': '236.8',
#   'childhood_blood_lead_level_screening': '503.7',
#   'childhood_lead_poisoning': '0.9',
#   'colorectal_cancer': '24.8',
#   'community_area': '27',
#   'community_area_name': 'East Garfield Park',
#   'crowded_housing': '7.5',
#   'dependency': '43.2',
#   'diabetes_related': '97.3',
#   'firearm_related': '37.1',
#   'general_fertility_rate': '80.8',
#   'gonorrhea_in_females': '2325.1',
#   'gonorrhea_in_males': '1730.2',
#   'infant_mortality_rate': '11',
#   'low_birth_weight': '17.5',
#   'lung_cancer': '56.3',
#   'no_high_school_diploma': '26.2',
#   'per_capita_income': '13596',
#   'prenatal_care_beginning_in_first_trimester': '73.2',
#   'preterm_births': '16.3',
#   'prostate_cancer_in_males': '78.1',
#   'stroke_cerebrovascular_disease': '47.5',
#   'teen_birth_rate': '93.2',
#   'tuberculosis': '13.6',
#   'unemployment': '16.4'},
#  {'assault_homicide': '12.7',
#   'below_poverty_level': '21.6',
#   'birth_rate': '18.2',
#   'breast_cancer_in_females': '33.4',
#   'cancer_all_sites': '202',
#   'childhood_blood_lead_level_screening': '396.7',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '19.2',
#   'community_area': '28',
#   'community_area_name': 'Near West Side',
#   'crowded_housing': '3.8',
#   'dependency': '22.9',
#   'diabetes_related': '62.3',
#   'firearm_related': '9.3',
#   'general_fertility_rate': '55.6',
#   'gonorrhea_in_females': '629.2',
#   'gonorrhea_in_males': '466.5',
#   'infant_mortality_rate': '9.1',
#   'low_birth_weight': '9',
#   'lung_cancer': '66.2',
#   'no_high_school_diploma': '11.2',
#   'per_capita_income': '41488',
#   'prenatal_care_beginning_in_first_trimester': '77.6',
#   'preterm_births': '10.5',
#   'prostate_cancer_in_males': '33.6',
#   'stroke_cerebrovascular_disease': '43.5',
#   'teen_birth_rate': '36.7',
#   'tuberculosis': '14.1',
#   'unemployment': '10.7'},
#  {'assault_homicide': '46.7',
#   'below_poverty_level': '38.6',
#   'birth_rate': '20.6',
#   'breast_cancer_in_females': '45.8',
#   'cancer_all_sites': '261.5',
#   'childhood_blood_lead_level_screening': '565.7',
#   'childhood_lead_poisoning': '1.4',
#   'colorectal_cancer': '34.8',
#   'community_area': '29',
#   'community_area_name': 'North Lawndale',
#   'crowded_housing': '7.2',
#   'dependency': '40.9',
#   'diabetes_related': '99.2',
#   'firearm_related': '37.6',
#   'general_fertility_rate': '86.3',
#   'gonorrhea_in_females': '2529.9',
#   'gonorrhea_in_males': '2236.3',
#   'infant_mortality_rate': '14.1',
#   'low_birth_weight': '15.3',
#   'lung_cancer': '61.7',
#   'no_high_school_diploma': '30.4',
#   'per_capita_income': '12548',
#   'prenatal_care_beginning_in_first_trimester': '75.8',
#   'preterm_births': '15.2',
#   'prostate_cancer_in_males': '54',
#   'stroke_cerebrovascular_disease': '70.2',
#   'teen_birth_rate': '108.9',
#   'tuberculosis': '9.3',
#   'unemployment': '18.5'},
#  {'assault_homicide': '11.1',
#   'below_poverty_level': '28.1',
#   'birth_rate': '19.5',
#   'breast_cancer_in_females': '13.2',
#   'cancer_all_sites': '127.4',
#   'childhood_blood_lead_level_screening': '605.9',
#   'childhood_lead_poisoning': '0.8',
#   'colorectal_cancer': '9.2',
#   'community_area': '30',
#   'community_area_name': 'South Lawndale',
#   'crowded_housing': '17.6',
#   'dependency': '33.1',
#   'diabetes_related': '65',
#   'firearm_related': '8.6',
#   'general_fertility_rate': '94.9',
#   'gonorrhea_in_females': '289.5',
#   'gonorrhea_in_males': '106.8',
#   'infant_mortality_rate': '5.9',
#   'low_birth_weight': '7.6',
#   'lung_cancer': '15.9',
#   'no_high_school_diploma': '58.7',
#   'per_capita_income': '10697',
#   'prenatal_care_beginning_in_first_trimester': '85.1',
#   'preterm_births': '9.6',
#   'prostate_cancer_in_males': '32.7',
#   'stroke_cerebrovascular_disease': '37.3',
#   'teen_birth_rate': '77.5',
#   'tuberculosis': '7.9',
#   'unemployment': '11.5'},
#  {'assault_homicide': '11.7',
#   'below_poverty_level': '27.2',
#   'birth_rate': '16.5',
#   'breast_cancer_in_females': '27.2',
#   'cancer_all_sites': '141.3',
#   'childhood_blood_lead_level_screening': '589',
#   'childhood_lead_poisoning': '0.8',
#   'colorectal_cancer': '11.9',
#   'community_area': '31',
#   'community_area_name': 'Lower West Side',
#   'crowded_housing': '10.4',
#   'dependency': '35.2',
#   'diabetes_related': '61.9',
#   'firearm_related': '11.7',
#   'general_fertility_rate': '68.2',
#   'gonorrhea_in_females': '92.3',
#   'gonorrhea_in_males': '78.7',
#   'infant_mortality_rate': '5.4',
#   'low_birth_weight': '4.5',
#   'lung_cancer': '27.8',
#   'no_high_school_diploma': '44.3',
#   'per_capita_income': '15467',
#   'prenatal_care_beginning_in_first_trimester': '80.8',
#   'preterm_births': '8.8',
#   'prostate_cancer_in_males': '14.3',
#   'stroke_cerebrovascular_disease': '39.2',
#   'teen_birth_rate': '49',
#   'tuberculosis': '11.4',
#   'unemployment': '13'},
#  {'assault_homicide': '0.7',
#   'below_poverty_level': '11.1',
#   'birth_rate': '9.4',
#   'breast_cancer_in_females': '20.2',
#   'cancer_all_sites': '120.1',
#   'childhood_blood_lead_level_screening': '297.3',
#   'childhood_lead_poisoning': '0.3',
#   'colorectal_cancer': '10.8',
#   'community_area': '32',
#   'community_area_name': 'Loop',
#   'crowded_housing': '2',
#   'dependency': '15.5',
#   'diabetes_related': '26.8',
#   'firearm_related': '4',
#   'general_fertility_rate': '27.7',
#   'gonorrhea_in_females': '129.9',
#   'gonorrhea_in_males': '200.5',
#   'infant_mortality_rate': '5.7',
#   'low_birth_weight': '5.3',
#   'lung_cancer': '29.2',
#   'no_high_school_diploma': '3.4',
#   'per_capita_income': '67699',
#   'prenatal_care_beginning_in_first_trimester': '78.2',
#   'preterm_births': '6.9',
#   'prostate_cancer_in_males': '17.2',
#   'stroke_cerebrovascular_disease': '39',
#   'teen_birth_rate': '1.3',
#   'tuberculosis': '6.5',
#   'unemployment': '4.2'},
#  {'assault_homicide': '4.8',
#   'below_poverty_level': '11.1',
#   'birth_rate': '21.4',
#   'breast_cancer_in_females': '31.9',
#   'cancer_all_sites': '169',
#   'childhood_blood_lead_level_screening': '301.3',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '19.2',
#   'community_area': '33',
#   'community_area_name': 'Near South Side',
#   'crowded_housing': '1.4',
#   'dependency': '21',
#   'diabetes_related': '61.5',
#   'firearm_related': '6.6',
#   'general_fertility_rate': '72.9',
#   'gonorrhea_in_females': '300.6',
#   'gonorrhea_in_males': '318.7',
#   'infant_mortality_rate': '4.8',
#   'low_birth_weight': '8.8',
#   'lung_cancer': '46.2',
#   'no_high_school_diploma': '7.1',
#   'per_capita_income': '60593',
#   'prenatal_care_beginning_in_first_trimester': '78.1',
#   'preterm_births': '10.9',
#   'prostate_cancer_in_males': '51.4',
#   'stroke_cerebrovascular_disease': '52.4',
#   'teen_birth_rate': '50.9',
#   'tuberculosis': '5',
#   'unemployment': '5.7'},
#  {'assault_homicide': '1.8',
#   'below_poverty_level': '35.8',
#   'birth_rate': '11.5',
#   'breast_cancer_in_females': '10.7',
#   'cancer_all_sites': '162.9',
#   'childhood_blood_lead_level_screening': '490.3',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '23.1',
#   'community_area': '34',
#   'community_area_name': 'Armour Square',
#   'crowded_housing': '5.9',
#   'dependency': '37.9',
#   'diabetes_related': '42.5',
#   'firearm_related': '1.8',
#   'general_fertility_rate': '57.1',
#   'gonorrhea_in_females': '222.6',
#   'gonorrhea_in_males': '218',
#   'infant_mortality_rate': '1.5',
#   'low_birth_weight': '12.4',
#   'lung_cancer': '54.3',
#   'no_high_school_diploma': '37.5',
#   'per_capita_income': '16942',
#   'prenatal_care_beginning_in_first_trimester': '79.1',
#   'preterm_births': '11.8',
#   'prostate_cancer_in_males': '17.2',
#   'stroke_cerebrovascular_disease': '38.7',
#   'teen_birth_rate': '16.2',
#   'tuberculosis': '22.7',
#   'unemployment': '11.6'},
#  {'assault_homicide': '13.6',
#   'below_poverty_level': '26.1',
#   'birth_rate': '10.3',
#   'breast_cancer_in_females': '34.3',
#   'cancer_all_sites': '269.9',
#   'childhood_blood_lead_level_screening': '482.2',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '33.2',
#   'community_area': '35',
#   'community_area_name': 'Douglas',
#   'crowded_housing': '1.6',
#   'dependency': '31',
#   'diabetes_related': '119.1',
#   'firearm_related': '9.1',
#   'general_fertility_rate': '42.2',
#   'gonorrhea_in_females': '1063.3',
#   'gonorrhea_in_males': '727.4',
#   'infant_mortality_rate': '13.4',
#   'low_birth_weight': '11.7',
#   'lung_cancer': '74.5',
#   'no_high_school_diploma': '16.9',
#   'per_capita_income': '23098',
#   'prenatal_care_beginning_in_first_trimester': '76',
#   'preterm_births': '10.2',
#   'prostate_cancer_in_males': '85.5',
#   'stroke_cerebrovascular_disease': '62.1',
#   'teen_birth_rate': '34.2',
#   'tuberculosis': '4.2',
#   'unemployment': '16.7'},
#  {'assault_homicide': '18.9',
#   'below_poverty_level': '38.1',
#   'birth_rate': '17.5',
#   'breast_cancer_in_females': '20.6',
#   'cancer_all_sites': '159.7',
#   'childhood_blood_lead_level_screening': '435.4',
#   'childhood_lead_poisoning': '0.3',
#   'colorectal_cancer': '14.5',
#   'community_area': '36',
#   'community_area_name': 'Oakland',
#   'crowded_housing': '3.5',
#   'dependency': '40.5',
#   'diabetes_related': '88.7',
#   'firearm_related': '12.6',
#   'general_fertility_rate': '63.9',
#   'gonorrhea_in_females': '1655.4',
#   'gonorrhea_in_males': '1629.3',
#   'infant_mortality_rate': '8.2',
#   'low_birth_weight': '13.5',
#   'lung_cancer': '54.5',
#   'no_high_school_diploma': '17.6',
#   'per_capita_income': '19312',
#   'prenatal_care_beginning_in_first_trimester': '75',
#   'preterm_births': '11.5',
#   'prostate_cancer_in_males': '54.2',
#   'stroke_cerebrovascular_disease': '43.7',
#   'teen_birth_rate': '54.5',
#   'tuberculosis': '6.7',
#   'unemployment': '26.6'},
#  {'assault_homicide': '49.6',
#   'below_poverty_level': '55.5',
#   'birth_rate': '11.9',
#   'breast_cancer_in_females': '8.5',
#   'cancer_all_sites': '258.9',
#   'childhood_blood_lead_level_screening': '489.9',
#   'childhood_lead_poisoning': '2.5',
#   'colorectal_cancer': '21.1',
#   'community_area': '37',
#   'community_area_name': 'Fuller Park',
#   'crowded_housing': '4.5',
#   'dependency': '38.2',
#   'diabetes_related': '111.7',
#   'firearm_related': '22.6',
#   'general_fertility_rate': '60.4',
#   'gonorrhea_in_females': '1061.9',
#   'gonorrhea_in_males': '1556.4',
#   'infant_mortality_rate': '22.6',
#   'low_birth_weight': '17.1',
#   'lung_cancer': '89.6',
#   'no_high_school_diploma': '33.7',
#   'per_capita_income': '9016',
#   'prenatal_care_beginning_in_first_trimester': '71.4',
#   'preterm_births': '14.3',
#   'prostate_cancer_in_males': '70.5',
#   'stroke_cerebrovascular_disease': '82.4',
#   'teen_birth_rate': '69.2',
#   'tuberculosis': '0',
#   'unemployment': '40'},
#  {'assault_homicide': '32.1',
#   'below_poverty_level': '28.3',
#   'birth_rate': '14.3',
#   'breast_cancer_in_females': '22.6',
#   'cancer_all_sites': '218.3',
#   'childhood_blood_lead_level_screening': '590.4',
#   'childhood_lead_poisoning': '1',
#   'colorectal_cancer': '27.7',
#   'community_area': '38',
#   'community_area_name': 'Grand Boulevard',
#   'crowded_housing': '2.7',
#   'dependency': '41.7',
#   'diabetes_related': '82.6',
#   'firearm_related': '25.8',
#   'general_fertility_rate': '58.2',
#   'gonorrhea_in_females': '1454.6',
#   'gonorrhea_in_males': '1680',
#   'infant_mortality_rate': '12.1',
#   'low_birth_weight': '12.7',
#   'lung_cancer': '63.8',
#   'no_high_school_diploma': '19.4',
#   'per_capita_income': '22056',
#   'prenatal_care_beginning_in_first_trimester': '74.2',
#   'preterm_births': '13.7',
#   'prostate_cancer_in_males': '39',
#   'stroke_cerebrovascular_disease': '46.7',
#   'teen_birth_rate': '54.8',
#   'tuberculosis': '13.2',
#   'unemployment': '20.6'},
#  {'assault_homicide': '15.2',
#   'below_poverty_level': '23.1',
#   'birth_rate': '12.2',
#   'breast_cancer_in_females': '30.9',
#   'cancer_all_sites': '196.4',
#   'childhood_blood_lead_level_screening': '397.9',
#   'childhood_lead_poisoning': '0.4',
#   'colorectal_cancer': '34.2',
#   'community_area': '39',
#   'community_area_name': 'Kenwood',
#   'crowded_housing': '2.3',
#   'dependency': '34.2',
#   'diabetes_related': '45.5',
#   'firearm_related': '17.4',
#   'general_fertility_rate': '51.1',
#   'gonorrhea_in_females': '610.2',
#   'gonorrhea_in_males': '549.1',
#   'infant_mortality_rate': '8.9',
#   'low_birth_weight': '11.4',
#   'lung_cancer': '49.1',
#   'no_high_school_diploma': '10.8',
#   'per_capita_income': '37519',
#   'prenatal_care_beginning_in_first_trimester': '77.6',
#   'preterm_births': '11.9',
#   'prostate_cancer_in_males': '46.2',
#   'stroke_cerebrovascular_disease': '31.5',
#   'teen_birth_rate': '25.7',
#   'tuberculosis': '0',
#   'unemployment': '11'},
#  {'assault_homicide': '44.6',
#   'below_poverty_level': '39.1',
#   'birth_rate': '19.3',
#   'breast_cancer_in_females': '26',
#   'cancer_all_sites': '258',
#   'childhood_blood_lead_level_screening': '502.4',
#   'childhood_lead_poisoning': '0.4',
#   'colorectal_cancer': '31.9',
#   'community_area': '40',
#   'community_area_name': 'Washington Park',
#   'crowded_housing': '4.9',
#   'dependency': '40.9',
#   'diabetes_related': '88.2',
#   'firearm_related': '39.5',
#   'general_fertility_rate': '72.1',
#   'gonorrhea_in_females': '2145.8',
#   'gonorrhea_in_males': '2058',
#   'infant_mortality_rate': '19.3',
#   'low_birth_weight': '17.7',
#   'lung_cancer': '79.8',
#   'no_high_school_diploma': '28.3',
#   'per_capita_income': '13087',
#   'prenatal_care_beginning_in_first_trimester': '74.9',
#   'preterm_births': '16.9',
#   'prostate_cancer_in_males': '67',
#   'stroke_cerebrovascular_disease': '43.3',
#   'teen_birth_rate': '82.6',
#   'tuberculosis': '5',
#   'unemployment': '23.2'},
#  {'assault_homicide': '5.8',
#   'below_poverty_level': '18.2',
#   'birth_rate': '9.7',
#   'breast_cancer_in_females': '33.6',
#   'cancer_all_sites': '144',
#   'childhood_blood_lead_level_screening': '369',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '11.7',
#   'community_area': '41',
#   'community_area_name': 'Hyde Park',
#   'crowded_housing': '2.5',
#   'dependency': '26.7',
#   'diabetes_related': '34',
#   'firearm_related': '5',
#   'general_fertility_rate': '33.9',
#   'gonorrhea_in_females': '216.6',
#   'gonorrhea_in_males': '168.4',
#   'infant_mortality_rate': '10.4',
#   'low_birth_weight': '5.9',
#   'lung_cancer': '34.9',
#   'no_high_school_diploma': '5.3',
#   'per_capita_income': '39243',
#   'prenatal_care_beginning_in_first_trimester': '80.3',
#   'preterm_births': '5.5',
#   'prostate_cancer_in_males': '24.1',
#   'stroke_cerebrovascular_disease': '26',
#   'teen_birth_rate': '7.6',
#   'tuberculosis': '5.3',
#   'unemployment': '6.9'},
#  {'assault_homicide': '31.1',
#   'below_poverty_level': '28.3',
#   'birth_rate': '15.1',
#   'breast_cancer_in_females': '32.9',
#   'cancer_all_sites': '241.3',
#   'childhood_blood_lead_level_screening': '444.3',
#   'childhood_lead_poisoning': '1.6',
#   'colorectal_cancer': '23.9',
#   'community_area': '42',
#   'community_area_name': 'Woodlawn',
#   'crowded_housing': '1.8',
#   'dependency': '37.6',
#   'diabetes_related': '82.1',
#   'firearm_related': '25',
#   'general_fertility_rate': '60.1',
#   'gonorrhea_in_females': '1382',
#   'gonorrhea_in_males': '1818.6',
#   'infant_mortality_rate': '11.5',
#   'low_birth_weight': '17.4',
#   'lung_cancer': '69.8',
#   'no_high_school_diploma': '17.9',
#   'per_capita_income': '18928',
#   'prenatal_care_beginning_in_first_trimester': '73.3',
#   'preterm_births': '16.3',
#   'prostate_cancer_in_males': '58',
#   'stroke_cerebrovascular_disease': '60',
#   'teen_birth_rate': '51.1',
#   'tuberculosis': '17.4',
#   'unemployment': '17.3'},
#  {'assault_homicide': '33.4',
#   'below_poverty_level': '31.5',
#   'birth_rate': '15.7',
#   'breast_cancer_in_females': '32.4',
#   'cancer_all_sites': '246',
#   'childhood_blood_lead_level_screening': '470.3',
#   'childhood_lead_poisoning': '1.1',
#   'colorectal_cancer': '25.1',
#   'community_area': '43',
#   'community_area_name': 'South Shore',
#   'crowded_housing': '2.9',
#   'dependency': '37.6',
#   'diabetes_related': '95.4',
#   'firearm_related': '30',
#   'general_fertility_rate': '67.9',
#   'gonorrhea_in_females': '1718.6',
#   'gonorrhea_in_males': '1357.1',
#   'infant_mortality_rate': '11.4',
#   'low_birth_weight': '13.8',
#   'lung_cancer': '70',
#   'no_high_school_diploma': '14.9',
#   'per_capita_income': '18366',
#   'prenatal_care_beginning_in_first_trimester': '71.9',
#   'preterm_births': '13.4',
#   'prostate_cancer_in_males': '54.8',
#   'stroke_cerebrovascular_disease': '53.2',
#   'teen_birth_rate': '65.9',
#   'tuberculosis': '11.7',
#   'unemployment': '17.7'},
#  {'assault_homicide': '45.2',
#   'below_poverty_level': '25.3',
#   'birth_rate': '14.4',
#   'breast_cancer_in_females': '41.9',
#   'cancer_all_sites': '213.5',
#   'childhood_blood_lead_level_screening': '418.3',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '24.1',
#   'community_area': '44',
#   'community_area_name': 'Chatham',
#   'crowded_housing': '2.2',
#   'dependency': '40',
#   'diabetes_related': '73.2',
#   'firearm_related': '37.9',
#   'general_fertility_rate': '71.3',
#   'gonorrhea_in_females': '1896.3',
#   'gonorrhea_in_males': '1855.8',
#   'infant_mortality_rate': '10.9',
#   'low_birth_weight': '15.4',
#   'lung_cancer': '51.5',
#   'no_high_school_diploma': '13.7',
#   'per_capita_income': '20320',
#   'prenatal_care_beginning_in_first_trimester': '72.5',
#   'preterm_births': '15.6',
#   'prostate_cancer_in_males': '47.9',
#   'stroke_cerebrovascular_disease': '50.3',
#   'teen_birth_rate': '68.2',
#   'tuberculosis': '8.2',
#   'unemployment': '19'},
#  {'assault_homicide': '22.1',
#   'below_poverty_level': '16.7',
#   'birth_rate': '13.3',
#   'breast_cancer_in_females': '33.8',
#   'cancer_all_sites': '239.6',
#   'childhood_blood_lead_level_screening': '434.8',
#   'childhood_lead_poisoning': '0.6',
#   'colorectal_cancer': '27.7',
#   'community_area': '45',
#   'community_area_name': 'Avalon Park',
#   'crowded_housing': '0.6',
#   'dependency': '41.9',
#   'diabetes_related': '83.9',
#   'firearm_related': '18.5',
#   'general_fertility_rate': '69.6',
#   'gonorrhea_in_females': '1139.9',
#   'gonorrhea_in_males': '2059.9',
#   'infant_mortality_rate': '11.4',
#   'low_birth_weight': '19.7',
#   'lung_cancer': '57.9',
#   'no_high_school_diploma': '13.3',
#   'per_capita_income': '23495',
#   'prenatal_care_beginning_in_first_trimester': '74.5',
#   'preterm_births': '14.6',
#   'prostate_cancer_in_males': '45.1',
#   'stroke_cerebrovascular_disease': '44.5',
#   'teen_birth_rate': '63.9',
#   'tuberculosis': '1.9',
#   'unemployment': '16.6'},
#  {'assault_homicide': '36.9',
#   'below_poverty_level': '28',
#   'birth_rate': '18.1',
#   'breast_cancer_in_females': '31.9',
#   'cancer_all_sites': '227.3',
#   'childhood_blood_lead_level_screening': '493.4',
#   'childhood_lead_poisoning': '1.6',
#   'colorectal_cancer': '21.1',
#   'community_area': '46',
#   'community_area_name': 'South Chicago',
#   'crowded_housing': '5.9',
#   'dependency': '43.1',
#   'diabetes_related': '86.9',
#   'firearm_related': '33.7',
#   'general_fertility_rate': '82.2',
#   'gonorrhea_in_females': '1774.7',
#   'gonorrhea_in_males': '893.5',
#   'infant_mortality_rate': '17.7',
#   'low_birth_weight': '13',
#   'lung_cancer': '50.9',
#   'no_high_school_diploma': '28.2',
#   'per_capita_income': '15393',
#   'prenatal_care_beginning_in_first_trimester': '75.3',
#   'preterm_births': '15.1',
#   'prostate_cancer_in_males': '56.3',
#   'stroke_cerebrovascular_disease': '50.6',
#   'teen_birth_rate': '76.8',
#   'tuberculosis': '6.9',
#   'unemployment': '17.7'},
#  {'assault_homicide': '70.3',
#   'below_poverty_level': '22.5',
#   'birth_rate': '12.9',
#   'breast_cancer_in_females': '7.6',
#   'cancer_all_sites': '191.2',
#   'childhood_blood_lead_level_screening': '375',
#   'childhood_lead_poisoning': '3.6',
#   'colorectal_cancer': '32.8',
#   'community_area': '47',
#   'community_area_name': 'Burnside',
#   'crowded_housing': '5.5',
#   'dependency': '40.4',
#   'diabetes_related': '86.1',
#   'firearm_related': '70.3',
#   'general_fertility_rate': '64',
#   'gonorrhea_in_females': '3108.8',
#   'gonorrhea_in_males': '1574.8',
#   'infant_mortality_rate': '13',
#   'low_birth_weight': '7.9',
#   'lung_cancer': '69.5',
#   'no_high_school_diploma': '18.6',
#   'per_capita_income': '13756',
#   'prenatal_care_beginning_in_first_trimester': '68.4',
#   'preterm_births': '13.2',
#   'prostate_cancer_in_males': '44',
#   'stroke_cerebrovascular_disease': '99.1',
#   'teen_birth_rate': '68.7',
#   'tuberculosis': '6.8',
#   'unemployment': '23.4'},
#  {'assault_homicide': '19.5',
#   'below_poverty_level': '12',
#   'birth_rate': '10',
#   'breast_cancer_in_females': '33.5',
#   'cancer_all_sites': '216.6',
#   'childhood_blood_lead_level_screening': '383.2',
#   'childhood_lead_poisoning': '0.3',
#   'colorectal_cancer': '36',
#   'community_area': '48',
#   'community_area_name': 'Calumet Heights',
#   'crowded_housing': '1.8',
#   'dependency': '42.3',
#   'diabetes_related': '81.4',
#   'firearm_related': '24.5',
#   'general_fertility_rate': '57.4',
#   'gonorrhea_in_females': '1188',
#   'gonorrhea_in_males': '1106.5',
#   'infant_mortality_rate': '13.9',
#   'low_birth_weight': '9.3',
#   'lung_cancer': '48',
#   'no_high_school_diploma': '11.2',
#   'per_capita_income': '28977',
#   'prenatal_care_beginning_in_first_trimester': '75',
#   'preterm_births': '16.4',
#   'prostate_cancer_in_males': '40.4',
#   'stroke_cerebrovascular_disease': '39.2',
#   'teen_birth_rate': '39.3',
#   'tuberculosis': '2.8',
#   'unemployment': '17.2'},
#  {'assault_homicide': '40.9',
#   'below_poverty_level': '19.5',
#   'birth_rate': '14.3',
#   'breast_cancer_in_females': '43.5',
#   'cancer_all_sites': '258.5',
#   'childhood_blood_lead_level_screening': '369.5',
#   'childhood_lead_poisoning': '1.9',
#   'colorectal_cancer': '32',
#   'community_area': '49',
#   'community_area_name': 'Roseland',
#   'crowded_housing': '3.1',
#   'dependency': '40.9',
#   'diabetes_related': '95.5',
#   'firearm_related': '37.7',
#   'general_fertility_rate': '68.8',
#   'gonorrhea_in_females': '1512',
#   'gonorrhea_in_males': '1725.3',
#   'infant_mortality_rate': '9.6',
#   'low_birth_weight': '12.2',
#   'lung_cancer': '70.3',
#   'no_high_school_diploma': '17.4',
#   'per_capita_income': '17974',
#   'prenatal_care_beginning_in_first_trimester': '69',
#   'preterm_births': '12.8',
#   'prostate_cancer_in_males': '57.6',
#   'stroke_cerebrovascular_disease': '55.6',
#   'teen_birth_rate': '79.7',
#   'tuberculosis': '7.9',
#   'unemployment': '17.8'},
#  {'assault_homicide': '32.2',
#   'below_poverty_level': '20.1',
#   'birth_rate': '14.3',
#   'breast_cancer_in_females': '34.6',
#   'cancer_all_sites': '262.5',
#   'childhood_blood_lead_level_screening': '398.5',
#   'childhood_lead_poisoning': '3.7',
#   'colorectal_cancer': '28.1',
#   'community_area': '50',
#   'community_area_name': 'Pullman',
#   'crowded_housing': '1.4',
#   'dependency': '42',
#   'diabetes_related': '78.5',
#   'firearm_related': '32.1',
#   'general_fertility_rate': '66.5',
#   'gonorrhea_in_females': '829.1',
#   'gonorrhea_in_males': '1480.4',
#   'infant_mortality_rate': '13.6',
#   'low_birth_weight': '11.2',
#   'lung_cancer': '83.8',
#   'no_high_school_diploma': '15.6',
#   'per_capita_income': '19007',
#   'prenatal_care_beginning_in_first_trimester': '81.3',
#   'preterm_births': '12.1',
#   'prostate_cancer_in_males': '92.9',
#   'stroke_cerebrovascular_disease': '65.3',
#   'teen_birth_rate': '67.9',
#   'tuberculosis': '2.7',
#   'unemployment': '21'},
#  {'assault_homicide': '41.3',
#   'below_poverty_level': '24.5',
#   'birth_rate': '15.8',
#   'breast_cancer_in_females': '25.3',
#   'cancer_all_sites': '224',
#   'childhood_blood_lead_level_screening': '427.1',
#   'childhood_lead_poisoning': '0.3',
#   'colorectal_cancer': '32.5',
#   'community_area': '51',
#   'community_area_name': 'South Deering',
#   'crowded_housing': '6',
#   'dependency': '41.4',
#   'diabetes_related': '80.6',
#   'firearm_related': '35.1',
#   'general_fertility_rate': '76.7',
#   'gonorrhea_in_females': '907',
#   'gonorrhea_in_males': '1018.2',
#   'infant_mortality_rate': '11.8',
#   'low_birth_weight': '14.9',
# ...
#   'cancer_all_sites': '235.2',
#   'childhood_blood_lead_level_screening': '555',
#   'childhood_lead_poisoning': '0.8',
#   'colorectal_cancer': '29.2',
#   'community_area': '61',
#   'community_area_name': 'New City',
#   'crowded_housing': '12.2',
#   'dependency': '42',
#   'diabetes_related': '83.7',
#   'firearm_related': '24.6',
#   'general_fertility_rate': '93.4',
#   'gonorrhea_in_females': '1052.6',
#   'gonorrhea_in_males': '579.7',
#   'infant_mortality_rate': '7.9',
#   'low_birth_weight': '11.8',
#   'lung_cancer': '69.4',
#   'no_high_school_diploma': '42.4',
#   'per_capita_income': '12524',
#   'prenatal_care_beginning_in_first_trimester': '75.9',
#   'preterm_births': '12.2',
#   'prostate_cancer_in_males': '40.7',
#   'stroke_cerebrovascular_disease': '50.2',
#   'teen_birth_rate': '94.3',
#   'tuberculosis': '9.3',
#   'unemployment': '17.4'},
#  {'assault_homicide': '5.9',
#   'below_poverty_level': '9.8',
#   'birth_rate': '20.8',
#   'breast_cancer_in_females': '12.1',
#   'cancer_all_sites': '180.6',
#   'childhood_blood_lead_level_screening': '492.6',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '11.5',
#   'community_area': '62',
#   'community_area_name': 'West Elsdon',
#   'crowded_housing': '8.7',
#   'dependency': '38.7',
#   'diabetes_related': '68.5',
#   'firearm_related': '7.7',
#   'general_fertility_rate': '92.3',
#   'gonorrhea_in_females': '122',
#   'gonorrhea_in_males': '115.9',
#   'infant_mortality_rate': '8.1',
#   'low_birth_weight': '4.6',
#   'lung_cancer': '57.8',
#   'no_high_school_diploma': '39.6',
#   'per_capita_income': '16938',
#   'prenatal_care_beginning_in_first_trimester': '81.2',
#   'preterm_births': '7.5',
#   'prostate_cancer_in_males': '44.7',
#   'stroke_cerebrovascular_disease': '42.6',
#   'teen_birth_rate': '45.5',
#   'tuberculosis': '4.5',
#   'unemployment': '13.5'},
#  {'assault_homicide': '10.8',
#   'below_poverty_level': '20.8',
#   'birth_rate': '21.8',
#   'breast_cancer_in_females': '23.4',
#   'cancer_all_sites': '171',
#   'childhood_blood_lead_level_screening': '590.3',
#   'childhood_lead_poisoning': '0.8',
#   'colorectal_cancer': '13.6',
#   'community_area': '63',
#   'community_area_name': 'Gage Park',
#   'crowded_housing': '17.4',
#   'dependency': '40.4',
#   'diabetes_related': '65',
#   'firearm_related': '11.1',
#   'general_fertility_rate': '93.2',
#   'gonorrhea_in_females': '171.6',
#   'gonorrhea_in_males': '149.2',
#   'infant_mortality_rate': '5.4',
#   'low_birth_weight': '6.8',
#   'lung_cancer': '34.1',
#   'no_high_school_diploma': '54.1',
#   'per_capita_income': '12014',
#   'prenatal_care_beginning_in_first_trimester': '80.4',
#   'preterm_births': '6.8',
#   'prostate_cancer_in_males': '41.1',
#   'stroke_cerebrovascular_disease': '51.2',
#   'teen_birth_rate': '61.4',
#   'tuberculosis': '7',
#   'unemployment': '14'},
#  {'assault_homicide': '9.4',
#   'below_poverty_level': '5.9',
#   'birth_rate': '14.6',
#   'breast_cancer_in_females': '23.6',
#   'cancer_all_sites': '189.4',
#   'childhood_blood_lead_level_screening': '302',
#   'childhood_lead_poisoning': '0.3',
#   'colorectal_cancer': '22.5',
#   'community_area': '64',
#   'community_area_name': 'Clearing',
#   'crowded_housing': '3.4',
#   'dependency': '36.4',
#   'diabetes_related': '72',
#   'firearm_related': '12.7',
#   'general_fertility_rate': '68.3',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '6.7',
#   'low_birth_weight': '7.4',
#   'lung_cancer': '58.6',
#   'no_high_school_diploma': '18.5',
#   'per_capita_income': '23920',
#   'prenatal_care_beginning_in_first_trimester': '85.8',
#   'preterm_births': '8',
#   'prostate_cancer_in_males': '18.7',
#   'stroke_cerebrovascular_disease': '53.5',
#   'teen_birth_rate': '38.7',
#   'tuberculosis': '0.9',
#   'unemployment': '9.6'},
#  {'assault_homicide': '10.7',
#   'below_poverty_level': '15.3',
#   'birth_rate': '18.8',
#   'breast_cancer_in_females': '16.9',
#   'cancer_all_sites': '145.1',
#   'childhood_blood_lead_level_screening': '508.3',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '15.7',
#   'community_area': '65',
#   'community_area_name': 'West Lawn',
#   'crowded_housing': '6.8',
#   'dependency': '41.9',
#   'diabetes_related': '61.5',
#   'firearm_related': '8.8',
#   'general_fertility_rate': '83.3',
#   'gonorrhea_in_females': '93.1',
#   'gonorrhea_in_males': '87.2',
#   'infant_mortality_rate': '8.4',
#   'low_birth_weight': '7.6',
#   'lung_cancer': '36.7',
#   'no_high_school_diploma': '33.4',
#   'per_capita_income': '15898',
#   'prenatal_care_beginning_in_first_trimester': '83.5',
#   'preterm_births': '8.3',
#   'prostate_cancer_in_males': '19.7',
#   'stroke_cerebrovascular_disease': '43.1',
#   'teen_birth_rate': '44.6',
#   'tuberculosis': '4.3',
#   'unemployment': '7.8'},
#  {'assault_homicide': '22.4',
#   'below_poverty_level': '22.2',
#   'birth_rate': '20.1',
#   'breast_cancer_in_females': '25',
#   'cancer_all_sites': '179.3',
#   'childhood_blood_lead_level_screening': '524.6',
#   'childhood_lead_poisoning': '1.2',
#   'colorectal_cancer': '26.1',
#   'community_area': '66',
#   'community_area_name': 'Chicago Lawn',
#   'crowded_housing': '6.5',
#   'dependency': '40',
#   'diabetes_related': '73',
#   'firearm_related': '19.4',
#   'general_fertility_rate': '85.3',
#   'gonorrhea_in_females': '1189.5',
#   'gonorrhea_in_males': '1159.9',
#   'infant_mortality_rate': '11.1',
#   'low_birth_weight': '9.4',
#   'lung_cancer': '42.9',
#   'no_high_school_diploma': '31.6',
#   'per_capita_income': '14405',
#   'prenatal_care_beginning_in_first_trimester': '78.4',
#   'preterm_births': '10.8',
#   'prostate_cancer_in_males': '22.1',
#   'stroke_cerebrovascular_disease': '61.7',
#   'teen_birth_rate': '67.4',
#   'tuberculosis': '5.3',
#   'unemployment': '11.9'},
#  {'assault_homicide': '47.2',
#   'below_poverty_level': '32.3',
#   'birth_rate': '20.3',
#   'breast_cancer_in_females': '39.2',
#   'cancer_all_sites': '247.6',
#   'childhood_blood_lead_level_screening': '450.6',
#   'childhood_lead_poisoning': '2.6',
#   'colorectal_cancer': '24.4',
#   'community_area': '67',
#   'community_area_name': 'West Englewood',
#   'crowded_housing': '6.9',
#   'dependency': '40.9',
#   'diabetes_related': '88.2',
#   'firearm_related': '39.3',
#   'general_fertility_rate': '93.3',
#   'gonorrhea_in_females': '2762.2',
#   'gonorrhea_in_males': '2545.7',
#   'infant_mortality_rate': '13.3',
#   'low_birth_weight': '16.1',
#   'lung_cancer': '66.3',
#   'no_high_school_diploma': '30.3',
#   'per_capita_income': '10559',
#   'prenatal_care_beginning_in_first_trimester': '63.6',
#   'preterm_births': '13.8',
#   'prostate_cancer_in_males': '75',
#   'stroke_cerebrovascular_disease': '64.6',
#   'teen_birth_rate': '116.9',
#   'tuberculosis': '10.9',
#   'unemployment': '34.7'},
#  {'assault_homicide': '45.1',
#   'below_poverty_level': '42.2',
#   'birth_rate': '20',
#   'breast_cancer_in_females': '32.9',
#   'cancer_all_sites': '252.2',
#   'childhood_blood_lead_level_screening': '401',
#   'childhood_lead_poisoning': '2.8',
#   'colorectal_cancer': '30.2',
#   'community_area': '68',
#   'community_area_name': 'Englewood',
#   'crowded_housing': '4.8',
#   'dependency': '43.4',
#   'diabetes_related': '101.8',
#   'firearm_related': '44.9',
#   'general_fertility_rate': '85.8',
#   'gonorrhea_in_females': '2594.9',
#   'gonorrhea_in_males': '2323.5',
#   'infant_mortality_rate': '13.4',
#   'low_birth_weight': '14.5',
#   'lung_cancer': '76.8',
#   'no_high_school_diploma': '29.4',
#   'per_capita_income': '11993',
#   'prenatal_care_beginning_in_first_trimester': '69.7',
#   'preterm_births': '13.1',
#   'prostate_cancer_in_males': '57.7',
#   'stroke_cerebrovascular_disease': '71.6',
#   'teen_birth_rate': '105.3',
#   'tuberculosis': '11.3',
#   'unemployment': '21.3'},
#  {'assault_homicide': '49.7',
#   'below_poverty_level': '25.6',
#   'birth_rate': '18.2',
#   'breast_cancer_in_females': '29.1',
#   'cancer_all_sites': '274.4',
#   'childhood_blood_lead_level_screening': '453.7',
#   'childhood_lead_poisoning': '1.9',
#   'colorectal_cancer': '31.5',
#   'community_area': '69',
#   'community_area_name': 'Greater Grand Crossing',
#   'crowded_housing': '4.2',
#   'dependency': '42.9',
#   'diabetes_related': '92.3',
#   'firearm_related': '44.6',
#   'general_fertility_rate': '82.4',
#   'gonorrhea_in_females': '2500.3',
#   'gonorrhea_in_males': '2034.2',
#   'infant_mortality_rate': '14.2',
#   'low_birth_weight': '12.9',
#   'lung_cancer': '77.5',
#   'no_high_school_diploma': '17.9',
#   'per_capita_income': '17213',
#   'prenatal_care_beginning_in_first_trimester': '72.3',
#   'preterm_births': '15.1',
#   'prostate_cancer_in_males': '70.3',
#   'stroke_cerebrovascular_disease': '58.2',
#   'teen_birth_rate': '84.3',
#   'tuberculosis': '4.8',
#   'unemployment': '18.9'},
#  {'assault_homicide': '12.4',
#   'below_poverty_level': '9.5',
#   'birth_rate': '14.7',
#   'breast_cancer_in_females': '37.2',
#   'cancer_all_sites': '229.3',
#   'childhood_blood_lead_level_screening': '368.3',
#   'childhood_lead_poisoning': '0.2',
#   'colorectal_cancer': '22.8',
#   'community_area': '70',
#   'community_area_name': 'Ashburn',
#   'crowded_housing': '4.2',
#   'dependency': '36.7',
#   'diabetes_related': '80.1',
#   'firearm_related': '11.6',
#   'general_fertility_rate': '69',
#   'gonorrhea_in_females': '529',
#   'gonorrhea_in_males': '602.9',
#   'infant_mortality_rate': '10.2',
#   'low_birth_weight': '9',
#   'lung_cancer': '62.8',
#   'no_high_school_diploma': '18.3',
#   'per_capita_income': '22078',
#   'prenatal_care_beginning_in_first_trimester': '82.4',
#   'preterm_births': '11.3',
#   'prostate_cancer_in_males': '44.5',
#   'stroke_cerebrovascular_disease': '47.4',
#   'teen_birth_rate': '38.3',
#   'tuberculosis': '4.4',
#   'unemployment': '8.8'},
#  {'assault_homicide': '37.6',
#   'below_poverty_level': '24.5',
#   'birth_rate': '15.1',
#   'breast_cancer_in_females': '41.9',
#   'cancer_all_sites': '243',
#   'childhood_blood_lead_level_screening': '393.8',
#   'childhood_lead_poisoning': '1.5',
#   'colorectal_cancer': '24.5',
#   'community_area': '71',
#   'community_area_name': 'Auburn Gresham',
#   'crowded_housing': '4.1',
#   'dependency': '42.1',
#   'diabetes_related': '83.6',
#   'firearm_related': '32.6',
#   'general_fertility_rate': '70.5',
#   'gonorrhea_in_females': '2032.2',
#   'gonorrhea_in_males': '1986.7',
#   'infant_mortality_rate': '15.6',
#   'low_birth_weight': '11.6',
#   'lung_cancer': '65.1',
#   'no_high_school_diploma': '19.5',
#   'per_capita_income': '16022',
#   'prenatal_care_beginning_in_first_trimester': '71.8',
#   'preterm_births': '13.9',
#   'prostate_cancer_in_males': '43.5',
#   'stroke_cerebrovascular_disease': '63.7',
#   'teen_birth_rate': '83.1',
#   'tuberculosis': '7.3',
#   'unemployment': '24.2'},
#  {'assault_homicide': '3.5',
#   'below_poverty_level': '5.2',
#   'birth_rate': '11',
#   'breast_cancer_in_females': '42',
#   'cancer_all_sites': '197.6',
#   'childhood_blood_lead_level_screening': '179.1',
#   'childhood_lead_poisoning': '1.3',
#   'colorectal_cancer': '24.8',
#   'community_area': '72',
#   'community_area_name': 'Beverly',
#   'crowded_housing': '0.7',
#   'dependency': '38.7',
#   'diabetes_related': '59.6',
#   'firearm_related': '3.5',
#   'general_fertility_rate': '60.7',
#   'gonorrhea_in_females': '195.5',
#   'gonorrhea_in_males': '469.5',
#   'infant_mortality_rate': '10',
#   'low_birth_weight': '4.9',
#   'lung_cancer': '47.9',
#   'no_high_school_diploma': '5.1',
#   'per_capita_income': '40107',
#   'prenatal_care_beginning_in_first_trimester': '84.8',
#   'preterm_births': '9.9',
#   'prostate_cancer_in_males': '44.7',
#   'stroke_cerebrovascular_disease': '57.2',
#   'teen_birth_rate': '11.9',
#   'tuberculosis': '0',
#   'unemployment': '7.8'},
#  {'assault_homicide': '38',
#   'below_poverty_level': '15.7',
#   'birth_rate': '12',
#   'breast_cancer_in_females': '47.9',
#   'cancer_all_sites': '260.6',
#   'childhood_blood_lead_level_screening': '371.4',
#   'childhood_lead_poisoning': '1.5',
#   'colorectal_cancer': '29.7',
#   'community_area': '73',
#   'community_area_name': 'Washington Heights',
#   'crowded_housing': '1.1',
#   'dependency': '42.4',
#   'diabetes_related': '79.5',
#   'firearm_related': '35.6',
#   'general_fertility_rate': '61',
#   'gonorrhea_in_females': '1298.2',
#   'gonorrhea_in_males': '1274.2',
#   'infant_mortality_rate': '11.2',
#   'low_birth_weight': '19.6',
#   'lung_cancer': '70',
#   'no_high_school_diploma': '15.6',
#   'per_capita_income': '19709',
#   'prenatal_care_beginning_in_first_trimester': '75.4',
#   'preterm_births': '16.2',
#   'prostate_cancer_in_males': '56.2',
#   'stroke_cerebrovascular_disease': '57.6',
#   'teen_birth_rate': '65',
#   'tuberculosis': '3',
#   'unemployment': '18.3'},
#  {'assault_homicide': '2.2',
#   'below_poverty_level': '3.1',
#   'birth_rate': '12.5',
#   'breast_cancer_in_females': '34.6',
#   'cancer_all_sites': '201.1',
#   'childhood_blood_lead_level_screening': '133.6',
#   'childhood_lead_poisoning': '0',
#   'colorectal_cancer': '24.8',
#   'community_area': '74',
#   'community_area_name': 'Mount Greenwood',
#   'crowded_housing': '1.1',
#   'dependency': '37',
#   'diabetes_related': '66.5',
#   'firearm_related': '7.4',
#   'general_fertility_rate': '59',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '3.3',
#   'low_birth_weight': '8.4',
#   'lung_cancer': '55',
#   'no_high_school_diploma': '4.5',
#   'per_capita_income': '34221',
#   'prenatal_care_beginning_in_first_trimester': '94.5',
#   'preterm_births': '15.1',
#   'prostate_cancer_in_males': '16.9',
#   'stroke_cerebrovascular_disease': '26.7',
#   'teen_birth_rate': '7.7',
#   'tuberculosis': '0',
#   'unemployment': '6.9'},
#  {'assault_homicide': '19.9',
#   'below_poverty_level': '13.7',
#   'birth_rate': '13.2',
#   'breast_cancer_in_females': '32.4',
#   'cancer_all_sites': '218.2',
#   'childhood_blood_lead_level_screening': '298.8',
#   'childhood_lead_poisoning': '1.3',
#   'colorectal_cancer': '27.1',
#   'community_area': '75',
#   'community_area_name': 'Morgan Park',
#   'crowded_housing': '0.8',
#   'dependency': '39.4',
#   'diabetes_related': '75.4',
#   'firearm_related': '15.8',
#   'general_fertility_rate': '67.5',
#   'gonorrhea_in_females': '800.5',
#   'gonorrhea_in_males': '741.1',
#   'infant_mortality_rate': '13.1',
#   'low_birth_weight': '10.6',
#   'lung_cancer': '50',
#   'no_high_school_diploma': '10.9',
#   'per_capita_income': '26185',
#   'prenatal_care_beginning_in_first_trimester': '74.5',
#   'preterm_births': '12.3',
#   'prostate_cancer_in_males': '39.8',
#   'stroke_cerebrovascular_disease': '47.9',
#   'teen_birth_rate': '46.7',
#   'tuberculosis': '2.6',
#   'unemployment': '14.9'},
#  {'assault_homicide': '5.6',
#   'below_poverty_level': '9.5',
#   'birth_rate': '15.8',
#   'breast_cancer_in_females': '20.5',
#   'cancer_all_sites': '138.5',
#   'childhood_blood_lead_level_screening': '182.9',
#   'childhood_lead_poisoning': '0.5',
#   'colorectal_cancer': '8.7',
#   'community_area': '76',
#   'community_area_name': "O'Hare",
#   'crowded_housing': '1.9',
#   'dependency': '26.5',
#   'diabetes_related': '47.3',
#   'firearm_related': '11.8',
#   'general_fertility_rate': '70',
#   'gonorrhea_in_males': '.',
#   'infant_mortality_rate': '2',
#   'low_birth_weight': '3.5',
#   'lung_cancer': '37.4',
#   'no_high_school_diploma': '11',
#   'per_capita_income': '29402',
#   'prenatal_care_beginning_in_first_trimester': '82',
#   'preterm_births': '5',
#   'prostate_cancer_in_males': '2.8',
#   'stroke_cerebrovascular_disease': '40.4',
#   'teen_birth_rate': '15.9',
#   'tuberculosis': '6.3',
#   'unemployment': '4.7'},
#  {'assault_homicide': '5.8',
#   'below_poverty_level': '16.6',
#   'birth_rate': '12.1',
#   'breast_cancer_in_females': '18.5',
#   'cancer_all_sites': '162',
#   'childhood_blood_lead_level_screening': '308.6',
#   'childhood_lead_poisoning': '0.9',
#   'colorectal_cancer': '16.2',
#   'community_area': '77',
#   'community_area_name': 'Edgewater',
#   'crowded_housing': '3.9',
#   'dependency': '23.4',
#   'diabetes_related': '48.8',
#   'firearm_related': '3.9',
#   'general_fertility_rate': '48.1',
#   'gonorrhea_in_females': '120.1',
#   'gonorrhea_in_males': '427.5',
#   'infant_mortality_rate': '6.9',
#   'low_birth_weight': '7.5',
#   'lung_cancer': '40.1',
#   'no_high_school_diploma': '9',
#   'per_capita_income': '33364',
#   'prenatal_care_beginning_in_first_trimester': '76.1',
#   'preterm_births': '7.4',
#   'prostate_cancer_in_males': '23.7',
#   'stroke_cerebrovascular_disease': '31.5',
#   'teen_birth_rate': '15.1',
#   'tuberculosis': '10.5',
#   'unemployment': '9'}]

# %%
# Create data frame from json data and orient by columns
income_sum_df = pd.DataFrame.from_dict(health_data, orient='columns')

# %%
# Print snapshot of Income Summary DataFrame
income_sum_df.head()
# Out:
#   assault_homicide below_poverty_level birth_rate breast_cancer_in_females  \
# 0              7.7                22.7       16.4                     23.3
# 1              5.8                15.1       17.3                     20.2
# 2              5.4                22.7       13.1                     21.3
# 3                5                 9.5       17.1                     21.7
# 4                1                 7.1       22.4                     16.6
#
#   cancer_all_sites childhood_blood_lead_level_screening  \
# 0            176.9                                364.7
# 1            155.9                                331.4
# 2            183.3                                353.7
# 3            153.2                                273.3
# 4            152.1                                178.1
#
#   childhood_lead_poisoning colorectal_cancer community_area  \
# 0                      0.5              25.3              1
# 1                        1              17.3              2
# 2                      0.5              20.5              3
# 3                      0.4               8.6              4
# 4                      0.9              26.1              5
#
#   community_area_name     ...      lung_cancer no_high_school_diploma  \
# 0         Rogers Park     ...             36.7                   18.1
# 1          West Ridge     ...               36                   19.6
# 2              Uptown     ...             50.5                   13.6
# 3      Lincoln Square     ...             43.1                   12.5
# 4        North Center     ...             42.4                    5.4
#
#   per_capita_income prenatal_care_beginning_in_first_trimester preterm_births  \
# 0             23714                                         73           11.2
# 1             21375                                       71.1            8.3
# 2             32355                                       77.7           10.3
# 3             35503                                       80.5            9.7
# 4             51615                                       80.4            9.8
#
#   prostate_cancer_in_males stroke_cerebrovascular_disease teen_birth_rate  \
# 0                     21.7                           33.7            40.8
# 1                     14.2                           34.7            29.9
# 2                     25.2                           41.7            35.1
# 3                     27.6                           36.9            38.4
# 4                     15.1                           41.6             8.4
#
#   tuberculosis unemployment
# 0         11.4          7.5
# 1          8.9          7.9
# 2         13.6          7.7
# 3          8.5          6.8
# 4          1.9          4.5
#
# [5 rows x 29 columns]

# %%
# Rename columns that we will use later for income levels
income_sum_df['Community Area'] = income_sum_df['community_area']
income_sum_df['Community Area Name'] = income_sum_df['community_area_name']
income_sum_df['Per Capita Income'] = income_sum_df['per_capita_income']

# Create new data frame for relevant columns
communities_incomes_df = [income_sum_df['Community Area'], 
                           income_sum_df['Community Area Name'], 
                           income_sum_df['Per Capita Income']}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-15d08e2eeaeb> in <module>
#       7 communities_incomes_df = {income_sum_df['Community Area'],
#       8                            income_sum_df['Community Area Name'],
# ----> 9                            income_sum_df['Per Capita Income']}
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
